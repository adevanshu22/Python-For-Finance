# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
# tickers = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE']
tickers = ['^GSPC', '^IXIC', '^GDAXI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1997-1-3')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
((ind_data / ind_data.iloc[0]) *100).plot(figsize = (15, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.head()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 1997-01-02       NaN       NaN       NaN
# 1997-01-03  0.014952  0.023409  0.015049
# 1997-01-06 -0.000508  0.004364  0.009409
# 1997-01-07  0.007463  0.008607 -0.004795
# 1997-01-08 -0.006399 -0.005558  0.009644

# %%
annual_ind_returns = ind_returns.mean()*250
print(annual_ind_returns)
# Out:
# ^GSPC     0.093098
# ^IXIC     0.131911
# ^GDAXI    0.082679
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '1995-1-1')['Adj Close']

# %%
data_2.head()
# Out:
#                   PG       ^GSPC         ^DJI
# Date
# 1995-01-03  8.014163  459.109985  3838.479980
# 1995-01-04  7.949918  460.709991  3857.649902
# 1995-01-05  7.837498  460.339996  3850.919922
# 1995-01-06  7.853554  460.679993  3867.409912
# 1995-01-09  7.821434  460.829987  3861.350098

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6768 entries, 1995-01-03 to 2021-11-16
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PG      6768 non-null   float64
#  1   ^GSPC   6768 non-null   float64
#  2   ^DJI    6768 non-null   float64
# dtypes: float64(3)
# memory usage: 211.5 KB

# %%
((data_2 / data_2.iloc[0]) * 100).plot(figsize = (15, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# From the above we can conclude that P&G outperform the market indices i.e. Dow jones as well as S&P500
